# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Dataset\Salary_data.csv")
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.shape
# Out:
# (30, 2)

# %%
data.info
# Out:
# <bound method DataFrame.info of     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# ...

# %% [markdown]
# Data Visualization

# %%
plt.scatter(data['YearsExperience'],data['Salary'])

# %%
import seaborn as sns
sns.scatterplot(x='YearsExperience',y='Salary',data=data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# Data Extraction

# %%
X=pd.DataFrame(data['YearsExperience']).values
Y=pd.DataFrame(data['Salary']).values
X
Y
# Out:
# array([[ 39343.],
#        [ 46205.],
#        [ 37731.],
#        [ 43525.],
#        [ 39891.],
#        [ 56642.],
#        [ 60150.],
#        [ 54445.],
#        [ 64445.],
#        [ 57189.],
#        [ 63218.],
#        [ 55794.],
#        [ 56957.],
#        [ 57081.],
#        [ 61111.],
#        [ 67938.],
#        [ 66029.],
#        [ 83088.],
#        [ 81363.],
#        [ 93940.],
#        [ 91738.],
#        [ 98273.],
#        [101302.],
#        [113812.],
#        [109431.],
#        [105582.],
#        [116969.],
#        [112635.],
#        [122391.],
#        [121872.]])

# %% [markdown]
# Data Splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y ,test_size=0.3,random_state=42)
# Random state for prevent shuffling
# Test size 0.3 means 30% for test and 70% for train

# %% [markdown]
# Model Creation

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction for Random Input

# %%
Y_pred=clf.predict(X_test)

# %%
clf.predict([[4.5]])
# Out:
# array([[67944.30609206]])

# %%
clf.predict([[4.5]]).flatten()[0]
# Out:
# 67944.3060920616

# %% [markdown]
# Model Performance Evaluation

# %%
print("Accuracy: ",clf.score(X_train,Y_train))
print("Accuracy: ",clf.score(X_test,Y_test))
# Out:
# Accuracy:  0.9574526669392872
# Accuracy:  0.9414466227178214

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(Y_test,Y_pred)
# Out:
# 6146.92300799458

# %%
a=Y_pred.flatten().tolist()
b=Y_test.flatten().tolist()
a
b
# Out:
# [112635.0,
#  67938.0,
#  113812.0,
#  83088.0,
#  64445.0,
#  57189.0,
#  122391.0,
#  109431.0,
#  56957.0]

# %% [markdown]
# Actual vs Predicted

# %%
pd.DataFrame({"Actual Salary":a, "Predicted Salary":b})
# Out:
#    Actual Salary  Predicted Salary
# 0  115573.622884          112635.0
# 1   71679.938782           67938.0
# 2  102498.908470          113812.0
# 3   75415.571471           83088.0
# 4   55803.499851           64445.0
# 5   60473.040713           57189.0
# 6  122110.980090          122391.0
# 7  107168.449332          109431.0
# 8   63274.765230           56957.0
