# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
    
    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

    def insert_at_index(self, data, index):
        if index == 0:
            self.insert_at_beginning(data)
            return
        new_node = Node(data)
        current = self.head
        for _ in range(index - 1):
            if current is None:
                print("Index out of range")
                return
            current = current.next
        new_node.next = current.next
        current.next = new_node  
    
    def delete_at_beginning(self):
        if self.head:
            self.head = self.head.next

    def delete_at_end(self):
        if not self.head:
            return
        if not self.head.next:
            self.head = None
            return
        current = self.head
        while current.next.next:
            current = current.next
        current.next = None

    def delete_at_index(self, index):
        if index == 0:
            self.delete_at_beginning()
            return
        current = self.head
        for _ in range(index - 1):
            if current is None:
                print("Index out of range")
                return
            current = current.next
        if current is None or current.next is None:
            print("Index out of range")
            return
        current.next = current.next.next
    
    def delete_by_value(self, value):
        current = self.head
        if current and current.data == value:
            self.head = current.next
            return
        prev = None
        while current:
            if current.data == value:
                prev.next = current.next
                return
            prev = current
            current = current.next

    def traverse(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

    def search(self, value):
        current = self.head
        index = 0
        while current:
            if current.data == value:
                print(f"Value {value} found at index {index}, memory address: {id(current)}")
                return
            current = current.next
            index += 1
        print(f"Value {value} not found in the linked list")

    def reverse_print(self, current):
        if current:
            self.reverse_print(current.next)
            print(current.data, end=" -> ")

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

def main():
    linked_list = LinkedList()

    while True:
        print("\nMenu:")
        print("1. Insert at beginning")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            data = int(input("Enter value: "))
            linked_list.insert_at_beginning(data)
            break
        else:
            print("Invalid choice, please try again.")
1
1
if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Insert at beginning

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

    def insert_at_index(self, data, index):
        if index == 0:
            self.insert_at_beginning(data)
            return
        new_node = Node(data)
        current = self.head
        for _ in range(index - 1):
            if current is None:
                print("Index out of range")
                return
            current = current.next
        new_node.next = current.next
        current.next = new_node

    def delete_at_beginning(self):
        if self.head:
            self.head = self.head.next

    def delete_at_end(self):
        if not self.head:
            return
        if not self.head.next:
            self.head = None
            return
        current = self.head
        while current.next.next:
            current = current.next
        current.next = None

    def delete_at_index(self, index):
        if index == 0:
            self.delete_at_beginning()
            return
        current = self.head
        for _ in range(index - 1):
            if current is None:
                print("Index out of range")
                return
            current = current.next
        if current is None or current.next is None:
            print("Index out of range")
            return
        current.next = current.next.next

    def delete_by_value(self, value):
        current = self.head
        if current and current.data == value:
            self.head = current.next
            return
        prev = None
        while current:
            if current.data == value:
                prev.next = current.next
                return
            prev = current
            current = current.next

    def traverse(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

    def search(self, value):
        current = self.head
        index = 0
        while current:
            if current.data == value:
                print(f"Value {value} found at index {index}, memory address: {id(current)}")
                return
            current = current.next
            index += 1
        print(f"Value {value} not found in the linked list")

    def reverse_print(self, current):
        if current:
            self.reverse_print(current.next)
            print(current.data, end=" -> ")

def main():
    linked_list = LinkedList()

    while True:
        print("\nMenu:")
        print("1. Insert at beginning")
        print("2. Insert at end")
        print("3. Insert at a particular index")
        print("4. Delete at beginning")
        print("5. Delete at end")
        print("6. Delete at a particular index")
        print("7. Delete by value")
        print("8. Traverse")
        print("9. Search")
        print("10. Reverse print")
        print("11. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            data = int(input("Enter value: "))
            linked_list.insert_at_beginning(data)
        elif choice == 2:
            data = int(input("Enter value: "))
            linked_list.insert_at_end(data)
        elif choice == 3:
            data = int(input("Enter value: "))
            index = int(input("Enter index: "))
            linked_list.insert_at_index(data, index)
        elif choice == 4:
            linked_list.delete_at_beginning()
        elif choice == 5:
            linked_list.delete_at_end()
        elif choice == 6:
            index = int(input("Enter index: "))
            linked_list.delete_at_index(index)
        elif choice == 7:
            value = int(input("Enter value to delete: "))
            linked_list.delete_by_value(value)
        elif choice == 8:
            linked_list.traverse()
        elif choice == 9:
            value = int(input("Enter value to search: "))
            linked_list.search(value)
        elif choice == 10:
            print("Linked list in reverse:")
            linked_list.reverse_print(linked_list.head)
            print("None")
        elif choice == 11:
            print("Exiting...")
            break
        else:
            print("Invalid choice, please try again.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 160
#     157             print("Invalid choice, please try again.")
#     159 if __name__ == "__main__":
# --> 160     main()
#
# Cell In[3], line 122, in main()
#     119 print("10. Reverse print")
#     120 print("11. Exit")
# --> 122 choice = int(input("Enter your choice: "))
#     124 if choice == 1:
#     125     data = int(input("Enter value: "))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_beginning(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    def insert_at_end(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current

    def insert_at_index(self, data, index):
        if index == 0:
            self.insert_at_beginning(data)
            return
        new_node = Node(data)
        current = self.head
        for _ in range(index - 1):
            if current is None:
                print("Index out of range")
                return
            current = current.next
        new_node.next = current.next
        new_node.prev = current
        if current.next:
            current.next.prev = new_node
        current.next = new_node

    def delete_at_beginning(self):
        if self.head:
            if self.head.next:
                self.head.next.prev = None
            self.head = self.head.next

    def delete_at_end(self):
        if not self.head:
            return
        if not self.head.next:
            self.head = None
            return
        current = self.head
        while current.next:
            current = current.next
        current.prev.next = None

    def delete_at_index(self, index):
        if index == 0:
            self.delete_at_beginning()
            return
        current = self.head
        for _ in range(index):
            if current is None:
                print("Index out of range")
                return
            current = current.next
        if current is None:
            print("Index out of range")
            return
        if current.next:
            current.next.prev = current.prev
        current.prev.next = current.next

    def delete_by_value(self, value):
        current = self.head
        while current:
            if current.data == value:
                if current.prev:
                    current.prev.next = current.next
                else:
                    self.head = current.next
                if current.next:
                    current.next.prev = current.prev
                return
            current = current.next

    def traverse(self):
        current = self.head
        while current:
            print(current.data, end=" <-> ")
            current = current.next
        print("None")

    def search(self, value):
        current = self.head
        index = 0
        while current:
            if current.data == value:
                print(f"Value {value} found at index {index}, memory address: {id(current)}")
                return
            current = current.next
            index += 1
        print(f"Value {value} not found in the linked list")

    def reverse_print(self):
        current = self.head
        if current:
            while current.next:
                current = current.next
            while current:
                print(current.data, end=" <-> ")
                current = current.prev
        print("None")

def main():
    linked_list = DoublyLinkedList()

    while True:
        print("\nMenu:")
        print("1. Insert at beginning")
        print("2. Insert at end")
        print("3. Insert at a particular index")
        print("4. Delete at beginning")
        print("5. Delete at end")
        print("6. Delete at a particular index")
        print("7. Delete by value")
        print("8. Traverse")
        print("9. Search")
        print("10. Reverse print")
        print("11. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            data = int(input("Enter value: "))
            linked_list.insert_at_beginning(data)
        elif choice == 2:
            data = int(input("Enter value: "))
            linked_list.insert_at_end(data)
        elif choice == 3:
            data = int(input("Enter value: "))
            index = int(input("Enter index: "))
            linked_list.insert_at_index(data, index)
        elif choice == 4:
            linked_list.delete_at_beginning()
        elif choice == 5:
            linked_list.delete_at_end()
        elif choice == 6:
            index = int(input("Enter index: "))
            linked_list.delete_at_index(index)
        elif choice == 7:
            value = int(input("Enter value to delete: "))
            linked_list.delete_by_value(value)
        elif choice == 8:
            linked_list.traverse()
        elif choice == 9:
            value = int(input("Enter value to search: "))
            linked_list.search(value)
        elif choice == 10:
            print("Linked list in reverse:")
            linked_list.reverse_print()
        elif choice == 11:
            print("Exiting...")
            break
        else:
            print("Invalid choice, please try again.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 1
# Enter value: 1
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 2
# Enter value: 2
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 3
# Enter value: 3
# Enter index: 4
# Index out of range
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 4
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 4
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 5
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 5
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 6
# Enter index: 6
# Index out of range
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 7
# Enter value to delete: 7
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 8
# None
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 9
# Enter value to search: 9
# Value 9 not found in the linked list
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 10
# Linked list in reverse:
# None
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 11
# Exiting...

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

class CircularHeaderDoublyLinkedList:
    def __init__(self):
        self.header = Node(None)  # Header node (sentinel node)
        self.header.prev = self.header
        self.header.next = self.header

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.header.next
        new_node.prev = self.header
        self.header.next.prev = new_node
        self.header.next = new_node

    def insert_at_end(self, data):
        new_node = Node(data)
        new_node.next = self.header
        new_node.prev = self.header.prev
        self.header.prev.next = new_node
        self.header.prev = new_node

    def insert_at_index(self, data, index):
        current = self.header
        for _ in range(index):
            if current.next == self.header:
                print("Index out of range")
                return
            current = current.next
        new_node = Node(data)
        new_node.next = current.next
        new_node.prev = current
        current.next.prev = new_node
        current.next = new_node

    def delete_at_beginning(self):
        if self.header.next != self.header:
            self.header.next = self.header.next.next
            self.header.next.prev = self.header

    def delete_at_end(self):
        if self.header.prev != self.header:
            self.header.prev = self.header.prev.prev
            self.header.prev.next = self.header

    def delete_at_index(self, index):
        current = self.header
        for _ in range(index):
            if current.next == self.header:
                print("Index out of range")
                return
            current = current.next
        if current.next != self.header:
            current.next = current.next.next
            current.next.prev = current

    def delete_by_value(self, value):
        current = self.header.next
        while current != self.header:
            if current.data == value:
                current.prev.next = current.next
                current.next.prev = current.prev
                return
            current = current.next

    def traverse(self):
        current = self.header.next
        while current != self.header:
            print(current.data, end=" <-> ")
            current = current.next
        print("None")

    def search(self, value):
        current = self.header.next
        index = 0
        while current != self.header:
            if current.data == value:
                print(f"Value {value} found at index {index}, memory address: {id(current)}")
                return
            current = current.next
            index += 1
        print(f"Value {value} not found in the linked list")

    def reverse_print(self):
        current = self.header.prev
        while current != self.header:
            print(current.data, end=" <-> ")
            current = current.prev
        print("None")

def main():
    linked_list = CircularHeaderDoublyLinkedList()

    while True:
        print("\nMenu:")
        print("1. Insert at beginning")
        print("2. Insert at end")
        print("3. Insert at a particular index")
        print("4. Delete at beginning")
        print("5. Delete at end")
        print("6. Delete at a particular index")
        print("7. Delete by value")
        print("8. Traverse")
        print("9. Search")
        print("10. Reverse print")
        print("11. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            data = int(input("Enter value: "))
            linked_list.insert_at_beginning(data)
        elif choice == 2:
            data = int(input("Enter value: "))
            linked_list.insert_at_end(data)
        elif choice == 3:
            data = int(input("Enter value: "))
            index = int(input("Enter index: "))
            linked_list.insert_at_index(data, index)
        elif choice == 4:
            linked_list.delete_at_beginning()
        elif choice == 5:
            linked_list.delete_at_end()
        elif choice == 6:
            index = int(input("Enter index: "))
            linked_list.delete_at_index(index)
        elif choice == 7:
            value = int(input("Enter value to delete: "))
            linked_list.delete_by_value(value)
        elif choice == 8:
            linked_list.traverse()
        elif choice == 9:
            value = int(input("Enter value to search: "))
            linked_list.search(value)
        elif choice == 10:
            print("Linked list in reverse:")
            linked_list.reverse_print()
        elif choice == 11:
            print("Exiting...")
            break
        else:
            print("Invalid choice, please try again.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 1
# Enter value: 1
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 2
# Enter value: 2
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 3
# Enter value: 3
# Enter index: 2
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 4
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 5
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 6
# Enter index: 5
# Index out of range
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 7
# Enter value to delete: 7
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 8
# 2 <-> None
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 9
# Enter value to search: 9
# Value 9 not found in the linked list
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 10
# Linked list in reverse:
# 2 <-> None
#
# Menu:
# 1. Insert at beginning
# 2. Insert at end
# 3. Insert at a particular index
# 4. Delete at beginning
# 5. Delete at end
# 6. Delete at a particular index
# 7. Delete by value
# 8. Traverse
# 9. Search
# 10. Reverse print
# 11. Exit
# Enter your choice: 11
# Exiting...
