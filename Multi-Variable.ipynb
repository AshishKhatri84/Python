# %% [markdown]
# Multi-variable Linear Regression

# %%
import pandas as pd
data2=pd.read_csv("Dataset\\advertising.csv")
data2
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# Data Visualization

# %%
import matplotlib.pyplot as plt
plt.scatter(data2["TV"],data2["Sales"])
plt.scatter(data2["Radio"],data2["Sales"])
plt.scatter(data2["Newspaper"],data2["Sales"])

# %%
import seaborn as sns
sns.scatterplot(x='TV',y='Sales',data=data2)
sns.scatterplot(x='Radio',y='Sales',data=data2)
sns.scatterplot(x='Newspaper',y='Sales',data=data2)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# Data Extraction

# %%
X=data2.drop({'Sales'},axis=1)
Y=data2['Sales']
print(X)
print(Y)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# Data Splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y ,test_size=0.3,random_state=42)

# %% [markdown]
# Model Creation

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction for Random Input

# %%
Y_pred=clf.predict(X_test)

# %%
clf.predict([[10,20,30]])
# Out:
# c:\Users\DELL\anaconda3\envs\indv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7.73037235])

# %% [markdown]
# Model Performance Evaluation

# %%
print("Accuracy: ",clf.score(X_train,Y_train))
print("Accuracy: ",clf.score(X_test,Y_test))
# Out:
# Accuracy:  0.8919647339302077
# Accuracy:  0.9091484341849799

# %%
from sklearn.metrics import root_mean_squared_error
root_mean_squared_error(Y_test,Y_pred)
# Out:
# 1.5942471691143592
